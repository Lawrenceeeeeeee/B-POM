# %%
import sys
sys.path.append('/Users/lawrence/Desktop/CUFE/大二下/大数据与金融/NLP/')

# %%
import bpom

bvid = "BV1uz421X7e1"
b = bpom.bpom(bvid)
print(b.comments)
# print(bpom.correlation_score("这个视频讲的太好了！"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import bpom
#       3 bvid = "BV1uz421X7e1"
#       4 b = bpom.bpom(bvid)
#
# File ~/Desktop/CUFE/大二下/大数据与金融/NLP/bpom.py:2
#       1 from src import get_bilibili_videos, get_comments, bvav, embedding
# ----> 2 from src.BertExecer import ModelInferer
#       3 from src.word_freq import word_freq
#       6 class bpom:
#
# File ~/Desktop/CUFE/大二下/大数据与金融/NLP/src/BertExecer.py:2
#       1 import torch
# ----> 2 from transformers import BertTokenizer, BertForSequenceClassification
#       3 from torch.nn.functional import softmax
#       5 class ModelInferer:
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      47     logging,
#      48 )
#      51 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File ~/miniforge3/lib/python3.10/site-packages/transformers/utils/__init__.py:18
#       1 #!/usr/bin/env python
#       2 # coding=utf-8
#       3
#    (...)
#      15 # See the License for the specific language governing permissions and
#      16 # limitations under the License.
# ---> 18 from huggingface_hub import get_full_repo_name  # for backward compatibility
#      19 from huggingface_hub.constants import HF_HUB_DISABLE_TELEMETRY as DISABLE_TELEMETRY  # for backward compatibility
#      20 from packaging import version
#
# File ~/miniforge3/lib/python3.10/site-packages/huggingface_hub/__init__.py:370, in _attach.<locals>.__getattr__(name)
#     368 elif name in attr_to_modules:
#     369     submod_path = f"{package_name}.{attr_to_modules[name]}"
# --> 370     submod = importlib.import_module(submod_path)
#     371     attr = getattr(submod, name)
#     373     # If the attribute lives in a file (module) with the same
#     374     # name as the attribute, ensure that the attribute and *not*
#     375     # the module is accessible on the package.
#
# File ~/miniforge3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniforge3/lib/python3.10/site-packages/huggingface_hub/hf_api.py:48
#      46 import requests
#      47 from requests.exceptions import HTTPError
# ---> 48 from tqdm.auto import tqdm as base_tqdm
#      49 from tqdm.contrib.concurrent import thread_map
#      51 from ._commit_api import (
#      52     CommitOperation,
#      53     CommitOperationAdd,
#    (...)
#      60     _warn_on_overwriting_operations,
#      61 )
#
# ModuleNotFoundError: No module named 'tqdm.auto'

# %%
b.fetch_comments()
# Out:
#              oid   timestamp          rpid        uid         uname  \
# 0     1351097913  1713349805  217297155376   41023166         冷酷的画家
# 1     1351097913  1713016179  216732536464  516323505         蓦然默默然
# 2     1351097913  1712587550  216015850144  341994451         凯爸爸刷大
# 3     1351097913  1712246809  215443578624  196367273     shabby的玩偶
# 4     1351097913  1712201671  215336998736    2461631        温蒂-玛贝尔
# ...          ...         ...           ...        ...           ...
# 1060  1351097913  1709113888  210239050512  525138013         易云小酒馆
# 1061  1351097913  1709113883  210238990320  531788598  beauty-lover
# 1062  1351097913  1709113881  210238951120  159067147     拿_单骑救主_破仑
# 1063  1351097913  1709113876  210238948144  600263750      SuperFox
# 1064  1351097913  1709113873  210239040816  401428799  201902132142
#
#                                                 content likes replies
# 0                                    去离子水淘宝能买到，好像两百多20升     0       0
# 1                                             总不能是双蒸水吧？     1       0
# 2                                         越纯的水，越容易脱水，笑死     1       0
# 3     为什么我在贩卖机里买的娃哈哈感觉巨难喝[捂脸][捂脸][捂脸]我同学喝了也这么说的[捂脸][...     0       0
# 4                                     机器应该是进口的吧？这么贵[吃瓜]     0       0
# ...                                                 ...   ...     ...
# 1060                                                 第一     0       1
# 1061                         前排第一 我爱毕导[doge][doge][星星眼]    17       2
# 1062                                             刚看完公众号     1       0
# 1063                              [打call][打call][打call]     0       0
# 1064                                                 第一     2       0
#
# [1065 rows x 8 columns]

# %%
b.run()
# Out:
#           oid   timestamp          rpid        uid      uname  \
# 0  1351097913  1713349805  217297155376   41023166      冷酷的画家
# 1  1351097913  1713016179  216732536464  516323505      蓦然默默然
# 2  1351097913  1712587550  216015850144  341994451      凯爸爸刷大
# 3  1351097913  1712246809  215443578624  196367273  shabby的玩偶
# 4  1351097913  1712201671  215336998736    2461631     温蒂-玛贝尔
#
#                                              content likes replies  \
# 0                                 去离子水淘宝能买到，好像两百多20升     0       0
# 1                                          总不能是双蒸水吧？     1       0
# 2                                      越纯的水，越容易脱水，笑死     1       0
# 3  为什么我在贩卖机里买的娃哈哈感觉巨难喝[捂脸][捂脸][捂脸]我同学喝了也这么说的[捂脸][...     0       0
# 4                                  机器应该是进口的吧？这么贵[吃瓜]     0       0
#
#    correlation_score
# 0           0.448786
# 1           0.159683
# 2           0.502384
# 3           0.439480
# 4           0.322103

# %%
b.comments.to_csv("comments.csv", index=False)

# %%
import plotly.graph_objects as go
import numpy as np

# 创建 x, y 的网格
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)

# 生成一个高度值 z，这里用的是二维高斯函数
z = np.sin(np.sqrt(x**2 + y**2))

# 创建图形对象
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])

# 更新布局，添加标题和调整视角
fig.update_layout(title='3D Surface Plot', autosize=False,
                  width=800, height=600,
                  margin=dict(l=65, r=50, b=65, t=90))

# 更新3D场景的设置
fig.update_scenes(
    aspectratio=dict(x=1, y=1, z=0.7),
    camera_eye=dict(x=1.5, y=1.5, z=0.5)
)

# 显示图形
fig.show()

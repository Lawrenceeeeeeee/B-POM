# %%
import sys
sys.path.append('/Users/lawrence/Desktop/CUFE/大二下/大数据与金融/NLP/')

# %%
import bpom

bvid = "BV1uz421X7e1"
b = bpom.bpom(bvid)
print(b.comments)
# print(bpom.correlation_score("这个视频讲的太好了！"))
# Out:
#           oid   timestamp          rpid        uid      uname  \
# 0  1351097913  1713349805  217297155376   41023166      冷酷的画家
# 1  1351097913  1713016179  216732536464  516323505      蓦然默默然
# 2  1351097913  1712587550  216015850144  341994451      凯爸爸刷大
# 3  1351097913  1712246809  215443578624  196367273  shabby的玩偶
# 4  1351097913  1712201671  215336998736    2461631     温蒂-玛贝尔
#
#                                              content likes replies
# 0                                 去离子水淘宝能买到，好像两百多20升     0       0
# 1                                          总不能是双蒸水吧？     1       0
# 2                                      越纯的水，越容易脱水，笑死     1       0
# 3  为什么我在贩卖机里买的娃哈哈感觉巨难喝[捂脸][捂脸][捂脸]我同学喝了也这么说的[捂脸][...     0       0
# 4                                  机器应该是进口的吧？这么贵[吃瓜]     0       0
# --2024-04-21 11:14:01--  https://cn-gdgz-cm-01-04.bilivideo.com/upgcxcode/63/11/1453571163/1453571163-1-30280.m4s?e=ig8euxZM2rNcNbdlhoNvNC8BqJIzNbfqXBvEqxTEto8BTrNvN0GvT90W5JZMkX_YN0MvXg8gNEV4NC8xNEV4N03eN0B5tZlqNxTEto8BTrNvNeZVuJ10Kj_g2UB02J0mN0B5tZlqNCNEto8BTrNvNC7MTX502C8f2jmMQJ6mqF2fka1mqx6gqj0eN0B599M=&uipk=5&nbs=1&deadline=1713676442&gen=playurlv2&os=bcache&oi=3745993437&trid=00004e7a6fd5bda741428b173960493cba96u&mid=0&platform=pc&upsig=e71b32faeeeb8c98fcd8a11e0ac288ea&uparams=e,uipk,nbs,deadline,gen,os,oi,trid,mid,platform&cdnid=87504&bvc=vod&nettype=0&orderid=0,3&buvid=&build=0&f=u_0_0&agrr=0&bw=21965&logo=80000000
# 正在解析主机 cn-gdgz-cm-01-04.bilivideo.com (cn-gdgz-cm-01-04.bilivideo.com)... 198.18.56.245
# 正在连接 cn-gdgz-cm-01-04.bilivideo.com (cn-gdgz-cm-01-04.bilivideo.com)|198.18.56.245|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：2262419 (2.2M) [video/mp4]
# 正在保存至: “temp/BV1uz421X7e1.m4a”
#
#      0K .......... .......... .......... .......... ..........  2%  878K 2s
#     50K .......... .......... .......... .......... ..........  4% 1.74M 2s
#    100K .......... .......... .......... .......... ..........  6%  833K 2s
#    150K .......... .......... .......... .......... ..........  9% 9.20M 2s
#    200K .......... .......... .......... .......... .......... 11% 2.68M 1s
#    250K .......... .......... .......... .......... .......... 13% 61.1M 1s
#    300K .......... .......... .......... .......... .......... 15% 17.6M 1s
#    350K .......... .......... .......... .......... .......... 18% 4.88M 1s
#    400K .......... .......... .......... .......... .......... 20% 7.17M 1s
#    450K .......... .......... .......... .......... .......... 22% 3.90M 1s
#    500K .......... .......... .......... .......... .......... 24% 7.54M 1s
#    550K .......... .......... .......... .......... .......... 27% 8.04M 1s
#    600K .......... .......... .......... .......... .......... 29% 8.62M 1s
#    650K .......... .......... .......... .......... .......... 31% 12.0M 0s
#    700K .......... .......... .......... .......... .......... 33% 9.06M 0s
#    750K .......... .......... .......... .......... .......... 36% 6.56M 0s
#    800K .......... .......... .......... .......... .......... 38% 48.6M 0s
#    850K .......... .......... .......... .......... .......... 40% 5.32M 0s
#    900K .......... .......... .......... .......... .......... 42% 12.5M 0s
#    950K .......... .......... .......... .......... .......... 45% 20.7M 0s
#   1000K .......... .......... .......... .......... .......... 47% 6.54M 0s
#   1050K .......... .......... .......... .......... .......... 49% 82.6M 0s
#   1100K .......... .......... .......... .......... .......... 52% 41.1M 0s
#   1150K .......... .......... .......... .......... .......... 54% 23.2M 0s
#   1200K .......... .......... .......... .......... .......... 56% 16.2M 0s
#   1250K .......... .......... .......... .......... .......... 58% 22.1M 0s
#   1300K .......... .......... .......... .......... .......... 61% 27.0M 0s
#   1350K .......... .......... .......... .......... .......... 63% 21.0M 0s
#   1400K .......... .......... .......... .......... .......... 65% 20.0M 0s
#   1450K .......... .......... .......... .......... .......... 67% 26.0M 0s
#   1500K .......... .......... .......... .......... .......... 70% 13.7M 0s
#   1550K .......... .......... .......... .......... .......... 72% 14.3M 0s
#   1600K .......... .......... .......... .......... .......... 74% 22.6M 0s
#   1650K .......... .......... .......... .......... .......... 76% 20.4M 0s
#   1700K .......... .......... .......... .......... .......... 79%  181M 0s
#   1750K .......... .......... .......... .......... .......... 81% 30.4M 0s
#   1800K .......... .......... .......... .......... .......... 83% 3.39M 0s
#   1850K .......... .......... .......... .......... .......... 85%  241M 0s
#   1900K .......... .......... .......... .......... .......... 88% 35.8M 0s
#   1950K .......... .......... .......... .......... .......... 90% 30.3M 0s
#   2000K .......... .......... .......... .......... .......... 92%  192M 0s
#   2050K .......... .......... .......... .......... .......... 95% 26.0M 0s
#   2100K .......... .......... .......... .......... .......... 97% 4.91M 0s
#   2150K .......... .......... .......... .......... .......... 99% 9.16M 0s
#   2200K .........                                             100% 35.6M=0.3s
#
# 2024-04-21 11:14:02 (6.60 MB/s) - 已保存 “temp/BV1uz421X7e1.m4a” [2262419/2262419])
#
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './temp/BV1uz421X7e1.m4a':
#   Metadata:
#     major_brand     : iso5
#     minor_version   : 1
#     compatible_brands: avc1iso5dsmsmsixdash
#     encoder         : Lavf58.29.100
#     description     : Packed by Bilibili XCoder v2.0.2
#   Duration: 00:01:43.13, start: 0.000000, bitrate: 175 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 9 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './temp/BV1uz421X7e1.wav':
#   Metadata:
#     major_brand     : iso5
#     minor_version   : 1
#     compatible_brands: avc1iso5dsmsmsixdash
#     description     : Packed by Bilibili XCoder v2.0.2
#     ISFT            : Lavf58.29.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, stereo, s16, 512 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    6445kB time=00:01:43.12 bitrate= 512.0kbits/s speed= 930x
# video:0kB audio:6445kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001182%
# error: input file not found 'true'
# whisper_init_from_file_with_params_no_state: loading model from '../whisper.cpp/models/ggml-medium.bin'
# whisper_model_load: loading model
# whisper_model_load: n_vocab       = 51865
# whisper_model_load: n_audio_ctx   = 1500
# whisper_model_load: n_audio_state = 1024
# whisper_model_load: n_audio_head  = 16
# whisper_model_load: n_audio_layer = 24
# whisper_model_load: n_text_ctx    = 448
# whisper_model_load: n_text_state  = 1024
# whisper_model_load: n_text_head   = 16
# whisper_model_load: n_text_layer  = 24
# whisper_model_load: n_mels        = 80
# whisper_model_load: ftype         = 1
# whisper_model_load: qntvr         = 0
# whisper_model_load: type          = 4 (medium)
# whisper_model_load: adding 1608 extra tokens
# whisper_model_load: n_langs       = 99
# whisper_backend_init: using Metal backend
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M2
# ggml_metal_init: picking default device: Apple M2
# ggml_metal_init: default.metallib not found, loading from source
# ggml_metal_init: GGML_METAL_PATH_RESOURCES = nil
# ggml_metal_init: loading '/Users/lawrence/Desktop/CUFE/大二下/大数据与金融/NLP/whisper.cpp/ggml-metal.metal'
# ggml_metal_init: GPU name:   Apple M2
# ggml_metal_init: GPU family: MTLGPUFamilyApple8  (1008)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction support   = true
# ggml_metal_init: simdgroup matrix mul. support = true
# ggml_metal_init: hasUnifiedMemory              = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 11453.25 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =  1462.12 MiB, ( 1464.00 / 10922.67)
# whisper_model_load:    Metal total size =  1533.14 MB
# whisper_model_load: model size    = 1533.14 MB
# whisper_backend_init: using Metal backend
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M2
# ggml_metal_init: picking default device: Apple M2
# ggml_metal_init: default.metallib not found, loading from source
# ggml_metal_init: GGML_METAL_PATH_RESOURCES = nil
# ggml_metal_init: loading '/Users/lawrence/Desktop/CUFE/大二下/大数据与金融/NLP/whisper.cpp/ggml-metal.metal'
# ggml_metal_init: GPU name:   Apple M2
# ggml_metal_init: GPU family: MTLGPUFamilyApple8  (1008)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction support   = true
# ggml_metal_init: simdgroup matrix mul. support = true
# ggml_metal_init: hasUnifiedMemory              = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 11453.25 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =   126.00 MiB, ( 1591.00 / 10922.67)
# whisper_init_state: kv self size  =  132.12 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =   140.62 MiB, ( 1731.62 / 10922.67)
# whisper_init_state: kv cross size =  147.46 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =    25.73 MiB, ( 1757.36 / 10922.67)
# whisper_init_state: compute buffer (conv)   =   28.68 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =   570.94 MiB, ( 2328.30 / 10922.67)
# whisper_init_state: compute buffer (encode) =  600.36 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =     5.86 MiB, ( 2334.16 / 10922.67)
# whisper_init_state: compute buffer (cross)  =    7.85 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =   130.83 MiB, ( 2464.98 / 10922.67)
# whisper_init_state: compute buffer (decode) =  138.87 MB
#
# system_info: n_threads = 4 / 8 | AVX = 0 | AVX2 = 0 | AVX512 = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | METAL = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 | CUDA = 0 | COREML = 0 | OPENVINO = 0
#
# main: processing 'temp/BV1uz421X7e1.wav' (1650005 samples, 103.1 sec), 4 threads, 1 processors, 5 beams + best of 5, lang = auto, task = transcribe, timestamps = 1 ...
#
# whisper_full_with_state: auto-detected language: zh (p = 0.997831)
# [00:00:00.000 --> 00:00:03.000]  两块一瓶的娃哈哈竟然是实验室必备?
# [00:00:03.000 --> 00:00:04.000]  那还真是。
# [00:00:04.000 --> 00:00:06.000]  实验室里摆的是娃哈哈,
# [00:00:06.000 --> 00:00:07.000]  冰农里写的是娃哈哈,
# [00:00:07.000 --> 00:00:09.000]  见过实验项目最多的人是娃哈哈。
# [00:00:09.000 --> 00:00:11.000]  呃……是王力宏。
# [00:00:11.000 --> 00:00:13.000]  为啥都用娃哈哈做科研呢?
# [00:00:13.000 --> 00:00:14.000]  一个字。
# [00:00:14.000 --> 00:00:15.000]  蠢。
# [00:00:15.000 --> 00:00:17.000]  相信大家搞科研都离不开鼠泥。
# [00:00:17.000 --> 00:00:19.000]  洗杯子配溶液打测谱,
# [00:00:19.000 --> 00:00:20.000]  水里有杂质这实验就没法做。
# [00:00:20.000 --> 00:00:22.000]  拿出家中常备的电导率测试一,
# [00:00:22.000 --> 00:00:24.000]  它可以测出溶液中的电导率。
# [00:00:24.000 --> 00:00:28.000]  事数越低,说明水中可以导入的粒子越少,水就越少。
# [00:00:28.000 --> 00:00:31.000]  接一杯北京的自然水一测,330。
# [00:00:31.000 --> 00:00:33.000]  接一杯半桶式的饮用水,其实……
# [00:00:33.000 --> 00:00:36.000]  电导率十以降,就能为生物和饮用纯净水。
# [00:00:36.000 --> 00:00:39.000]  而这瓶娃哈哈测出来只有1.4。
# [00:00:39.000 --> 00:00:42.000]  第二个字。
# [00:00:42.000 --> 00:00:44.000]  性价比较高。
# [00:00:44.000 --> 00:00:46.000]  你以为的纯水多不就H2O吗?
# [00:00:46.000 --> 00:00:49.000]  一氧化氧氢水乎一烧就完事了。
# [00:00:49.000 --> 00:00:52.000]  但其实,获得一瓶高程度的水很难。
# [00:00:52.000 --> 00:00:54.000]  我读博的时候做的就是这个水磨。
# [00:00:54.000 --> 00:00:58.000]  但是我们实验室不用娃哈哈,我们用的是纯水机。
# [00:00:58.000 --> 00:01:01.000]  水进去先吸附过滤去除它的固体颗粒,
# [00:01:01.000 --> 00:01:05.000]  再经过反渗的磨去除大部分溶解性的盐和一些微生物。
# [00:01:05.000 --> 00:01:08.000]  最后经过一个粒子交换数值就得到了超纯水。
# [00:01:08.000 --> 00:01:12.000]  但是你猜这么一套东西,一套机器要多少钱?
# [00:01:12.000 --> 00:01:14.000]  二十吧。
# [00:01:14.000 --> 00:01:19.000]  如果实验室没有纯水机,C的把这些大牌子的高纯水一升一降要一千块。
# [00:01:19.000 --> 00:01:22.000]  一般课题组那是砸锅卖铁也用不起啊。
# [00:01:22.000 --> 00:01:25.000]  我用了三年高程水,几个费用?
# [00:01:25.000 --> 00:01:30.000]  实验室用不完,路门还没水纯,这娃哈哈纯不纯?
# [00:01:30.000 --> 00:01:33.000]  我们这些搞实验的还不知道吗?
# [00:01:33.000 --> 00:01:38.000]  这娃哈哈纯不纯?比起高程水是没那么纯。
# [00:01:38.000 --> 00:01:42.000]  但确实能应对一些科研事情,而且两块一瓶你要啥子去扯?
# [00:01:42.000 --> 00:01:43.000]  我只知道自己在哭
# output_lrc: saving output to 'temp/BV1uz421X7e1.lrc'
#
# whisper_print_timings:     load time =   649.09 ms
# whisper_print_timings:     fallbacks =   1 p /   0 h
# whisper_print_timings:      mel time =    50.99 ms
# whisper_print_timings:   sample time =  2195.14 ms /  3676 runs (    0.60 ms per run)
# whisper_print_timings:   encode time =  6050.34 ms /     6 runs ( 1008.39 ms per run)
# whisper_print_timings:   decode time =   195.44 ms /     6 runs (   32.57 ms per run)
# whisper_print_timings:   batchd time = 22244.88 ms /  3652 runs (    6.09 ms per run)
# whisper_print_timings:   prompt time =   598.20 ms /   714 runs (    0.84 ms per run)
# whisper_print_timings:    total time = 32003.23 ms
# ggml_metal_free: deallocating
# ggml_metal_free: deallocating
#              oid   timestamp          rpid        uid         uname  \
# 0     1351097913  1713349805  217297155376   41023166         冷酷的画家
# 1     1351097913  1713016179  216732536464  516323505         蓦然默默然
# 2     1351097913  1712587550  216015850144  341994451         凯爸爸刷大
# 3     1351097913  1712246809  215443578624  196367273     shabby的玩偶
# 4     1351097913  1712201671  215336998736    2461631        温蒂-玛贝尔
# ...          ...         ...           ...        ...           ...
# 1060  1351097913  1709113888  210239050512  525138013         易云小酒馆
# 1061  1351097913  1709113883  210238990320  531788598  beauty-lover
# 1062  1351097913  1709113881  210238951120  159067147     拿_单骑救主_破仑
# 1063  1351097913  1709113876  210238948144  600263750      SuperFox
# 1064  1351097913  1709113873  210239040816  401428799  201902132142
#
#                                                 content likes replies
# 0                                    去离子水淘宝能买到，好像两百多20升     0       0
# 1                                             总不能是双蒸水吧？     1       0
# 2                                         越纯的水，越容易脱水，笑死     1       0
# 3     为什么我在贩卖机里买的娃哈哈感觉巨难喝[捂脸][捂脸][捂脸]我同学喝了也这么说的[捂脸][...     0       0
# 4                                     机器应该是进口的吧？这么贵[吃瓜]     0       0
# ...                                                 ...   ...     ...
# 1060                                                 第一     0       1
# 1061                         前排第一 我爱毕导[doge][doge][星星眼]    17       2
# 1062                                             刚看完公众号     1       0
# 1063                              [打call][打call][打call]     0       0
# 1064                                                 第一     2       0
#
# [1065 rows x 8 columns]

# %%
b.fetch_comments()
# Out:
#              oid   timestamp          rpid        uid         uname  \
# 0     1351097913  1713349805  217297155376   41023166         冷酷的画家
# 1     1351097913  1713016179  216732536464  516323505         蓦然默默然
# 2     1351097913  1712587550  216015850144  341994451         凯爸爸刷大
# 3     1351097913  1712246809  215443578624  196367273     shabby的玩偶
# 4     1351097913  1712201671  215336998736    2461631        温蒂-玛贝尔
# ...          ...         ...           ...        ...           ...
# 1060  1351097913  1709113888  210239050512  525138013         易云小酒馆
# 1061  1351097913  1709113883  210238990320  531788598  beauty-lover
# 1062  1351097913  1709113881  210238951120  159067147     拿_单骑救主_破仑
# 1063  1351097913  1709113876  210238948144  600263750      SuperFox
# 1064  1351097913  1709113873  210239040816  401428799  201902132142
#
#                                                 content likes replies
# 0                                    去离子水淘宝能买到，好像两百多20升     0       0
# 1                                             总不能是双蒸水吧？     1       0
# 2                                         越纯的水，越容易脱水，笑死     1       0
# 3     为什么我在贩卖机里买的娃哈哈感觉巨难喝[捂脸][捂脸][捂脸]我同学喝了也这么说的[捂脸][...     0       0
# 4                                     机器应该是进口的吧？这么贵[吃瓜]     0       0
# ...                                                 ...   ...     ...
# 1060                                                 第一     0       1
# 1061                         前排第一 我爱毕导[doge][doge][星星眼]    17       2
# 1062                                             刚看完公众号     1       0
# 1063                              [打call][打call][打call]     0       0
# 1064                                                 第一     2       0
#
# [1065 rows x 8 columns]

# %%
b.run()
# Out:
#           oid   timestamp          rpid        uid      uname  \
# 0  1351097913  1713349805  217297155376   41023166      冷酷的画家
# 1  1351097913  1713016179  216732536464  516323505      蓦然默默然
# 2  1351097913  1712587550  216015850144  341994451      凯爸爸刷大
# 3  1351097913  1712246809  215443578624  196367273  shabby的玩偶
# 4  1351097913  1712201671  215336998736    2461631     温蒂-玛贝尔
#
#                                              content likes replies  \
# 0                                 去离子水淘宝能买到，好像两百多20升     0       0
# 1                                          总不能是双蒸水吧？     1       0
# 2                                      越纯的水，越容易脱水，笑死     1       0
# 3  为什么我在贩卖机里买的娃哈哈感觉巨难喝[捂脸][捂脸][捂脸]我同学喝了也这么说的[捂脸][...     0       0
# 4                                  机器应该是进口的吧？这么贵[吃瓜]     0       0
#
#    correlation_score
# 0           0.448786
# 1           0.159683
# 2           0.502384
# 3           0.439480
# 4           0.322103

# %%
b.comments.to_csv("comments.csv", index=False)
